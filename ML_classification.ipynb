# %% [markdown]
# # Import modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as skl
import seaborn as sns
from im_tutorials.data.cordis import cordis_table

# %% [markdown]
# # Import Data

# %%
cordis_orgs_df = cordis_table('organisations')
cordis_project_orgs_df = cordis_table('project_organisations')
cordis_projects_df = cordis_table('projects')
cordis_full_df = cordis_project_orgs_df.merge(
    cordis_projects_df, left_on='project_rcn', right_on='rcn', how='left'
)
cordis_full_df = cordis_full_df.merge(
    cordis_orgs_df, left_on='organization_id', right_on='id', how='left'
)
cordis_full_df.head()
cordis_full_df.columns
# Out:
# Index(['project_rcn', 'organization_id', 'activity_type', 'address',
#        'contribution', 'type', 'website_x', 'rcn', 'acronym', 'end_date_code',
#        'ec_contribution', 'framework', 'funding_scheme', 'funded_under',
#        'objective', 'project_description', 'start_date_code', 'status',
#        'title', 'total_cost', 'website_y', 'id', 'name', 'country_code',
#        'country_name'],
#       dtype='object')

# %% [markdown]
# # Add labels to Dataframe

# %%
cordis_full_df_sorted = cordis_full_df.sort_values(by=['organization_id', 'start_date_code'])
cordis_full_df_sorted = cordis_full_df_sorted.reset_index(drop=True)
cordis_full_df_sorted['num_success'] = cordis_full_df_sorted.groupby('organization_id').cumcount()
cordis_full_df_sorted_temp = cordis_full_df_sorted[['organization_id','num_success']]
cordis_full_df_sorted_temp = cordis_full_df_sorted_temp.groupby(by=['organization_id']).max()
cordis_full_df_sorted_temp.rename(columns={'num_success':'multiple_success'}, inplace=True)
cordis_full_df_sorted = cordis_full_df_sorted.merge(
    cordis_full_df_sorted_temp, on='organization_id', how='left'
)
cordis_full_df_sorted['group_multiple_success'] = (cordis_full_df_sorted['multiple_success'] > 0) * 1
cordis_full_df_sorted.columns
# Out:
# Index(['project_rcn', 'organization_id', 'activity_type', 'address',
#        'contribution', 'type', 'website_x', 'rcn', 'acronym', 'end_date_code',
#        'ec_contribution', 'framework', 'funding_scheme', 'funded_under',
#        'objective', 'project_description', 'start_date_code', 'status',
#        'title', 'total_cost', 'website_y', 'id', 'name', 'country_code',
#        'country_name', 'num_success', 'multiple_success',
#        'group_multiple_success'],
#       dtype='object')

# %%
cordis_full_df_sorted
# Out:
#         project_rcn  organization_id  \
# 0            101114        -99679701
# 1            206608        -99552481
# 2            189108        -99525116
# 3             90329        -99524889
# 4            206615        -99449792
# ...             ...              ...
# 251035        98892        999997930
# 251036       107868        999997930
# 251037       109814        999997930
# 251038       210724        999997930
# 251039       212174        999997930
#
#                                             activity_type  \
# 0       Private for-profit entities (excluding Higher ...
# 1                                                   Other
# 2
# 3
# 4                                                   Other
# ...                                                   ...
# 251035                             Research Organisations
# 251036                             Research Organisations
# 251037                             Research Organisations
# 251038                             Research Organisations
# 251039                             Research Organisations
#
#                                                   address  contribution  \
# 0       {'city': 'FARNBOROUGH', 'street': 'WARWICK HOU...        439152
# 1       {'city': 'Hanoi', 'street': 'Dai Co Viet 1', '...         98582
# 2       {'city': 'ATHENS', 'street': 'KIFISSIAS 99', '...             0
# 3       {'city': 'COPENHAGEN', 'street': 'H.C. Anderse...             0
# 4       {'city': 'Zurich-Airport', 'street': 'P.O.Box ...         83920
# ...                                                   ...           ...
# 251035  {'city': 'PARIS', 'street': 'RUE MICHEL ANGE 3...        250659
# 251036  {'city': 'PARIS', 'street': 'RUE MICHEL ANGE 3...        280254
# 251037  {'city': 'PARIS', 'street': 'RUE MICHEL ANGE 3...        261385
# 251038  {'city': 'PARIS', 'street': 'RUE MICHEL ANGE 3...         75000
# 251039  {'city': 'PARIS', 'street': 'RUE MICHEL ANGE 3...        173076
#
#                type                  website_x     rcn              acronym  \
# 0       participant         www.baesystems.com  101114        ACTUATION2015
# 1       participant  http://www1.hut.edu.vn/en  206608               SEAGAL
# 2       participant                             189108               VIMSEN
# 3       participant                              90329            SETATWORK
# 4       participant                www.rega.ch  206615                HEDGE
# ...             ...                        ...     ...                  ...
# 251035  coordinator                www.cnrs.fr   98892   Bird Vocal Network
# 251036  coordinator                www.cnrs.fr  107868  gas trapping in ice
# 251037  coordinator                www.cnrs.fr  109814             NIEDPWIT
# 251038  coordinator                www.cnrs.fr  210724   SRBMETABONOXSTRESS
# 251039  coordinator                www.cnrs.fr  212174         NanoOsmDiode
#
#        end_date_code  ...                                              title  \
# 0         2016-04-30  ...  ACTUATION 2015: Modular Electro Mechanical Act...
# 1         2010-11-14  ...  South East Asia centre on European GNSS for in...
# 2         2017-01-31  ...  VIMSEN: Virtual Microgrids for Smart Energy Ne...
# 3         2010-08-31  ...  Sustainable energy technology at work: themati...
# 4         2011-05-14  ...                  Helicopters Deploy GNSS in Europe
# ...              ...  ...                                                ...
# 251035           NaT  ...  Individual signatures in a vocal network: the ...
# 251036           NaT  ...  Experimental study of gas strapping in amorpho...
# 251037           NaT  ...  New Insights in Eating Disorders Paving the Wa...
# 251038           NaT  ...  Metabonomic Analysis of the Sulfate-Reducing B...
# 251039           NaT  ...  Development of a high-performance nanofluidic ...
#
#        total_cost                     website_y         id  \
# 0        34373653  http://www.actuation2015.eu/  -99679701
# 1          548229                                -99552481
# 2         3331399                                -99525116
# 3         1207388                                -99524889
# 4         1192235                                -99449792
# ...           ...                           ...        ...
# 251035     250659                                999997930
# 251036     280254                                999997930
# 251037     261385                                999997930
# 251038      75000                                999997930
# 251039     173076                                999997930
#
#                                                      name country_code  \
# 0                        BAE SYSTEMS (OPERATIONS) LIMITED           GB
# 1                          Hanoi University of Technology           VN
# 2                      COSMOTE KINITES TILEPIKOINONIES AE           GR
# 3                      CONFEDERATION OF DANISH INDUSTRIES           DK
# 4                                 Swiss Air Ambulance LTD           CH
# ...                                                   ...          ...
# 251035  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS           FR
# 251036  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS           FR
# 251037  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS           FR
# 251038  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS           FR
# 251039  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS           FR
#
#           country_name num_success multiple_success  group_multiple_success
# 0       United Kingdom           0                0                       0
# 1              Vietnam           0                0                       0
# 2               Greece           0                0                       0
# 3              Denmark           0                0                       0
# 4          Switzerland           0                0                       0
# ...                ...         ...              ...                     ...
# 251035          France        2695             2699                       1
# 251036          France        2696             2699                       1
# 251037          France        2697             2699                       1
# 251038          France        2698             2699                       1
# 251039          France        2699             2699                       1
#
# [251040 rows x 28 columns]

# %%
def fundedUnder2Title(x):
    return x[0]['title']
cordis_full_df_sorted['funded_under_title'] = cordis_full_df_sorted['funded_under'].apply(fundedUnder2Title)
cordis_full_df_sorted
# Out:
#         project_rcn  organization_id  \
# 0            101114        -99679701
# 1            206608        -99552481
# 2            189108        -99525116
# 3             90329        -99524889
# 4            206615        -99449792
# ...             ...              ...
# 251035        98892        999997930
# 251036       107868        999997930
# 251037       109814        999997930
# 251038       210724        999997930
# 251039       212174        999997930
#
#                                             activity_type  \
# 0       Private for-profit entities (excluding Higher ...
# 1                                                   Other
# 2
# 3
# 4                                                   Other
# ...                                                   ...
# 251035                             Research Organisations
# 251036                             Research Organisations
# 251037                             Research Organisations
# 251038                             Research Organisations
# 251039                             Research Organisations
#
#                                                   address  contribution  \
# 0       {'city': 'FARNBOROUGH', 'street': 'WARWICK HOU...        439152
# 1       {'city': 'Hanoi', 'street': 'Dai Co Viet 1', '...         98582
# 2       {'city': 'ATHENS', 'street': 'KIFISSIAS 99', '...             0
# 3       {'city': 'COPENHAGEN', 'street': 'H.C. Anderse...             0
# 4       {'city': 'Zurich-Airport', 'street': 'P.O.Box ...         83920
# ...                                                   ...           ...
# 251035  {'city': 'PARIS', 'street': 'RUE MICHEL ANGE 3...        250659
# 251036  {'city': 'PARIS', 'street': 'RUE MICHEL ANGE 3...        280254
# 251037  {'city': 'PARIS', 'street': 'RUE MICHEL ANGE 3...        261385
# 251038  {'city': 'PARIS', 'street': 'RUE MICHEL ANGE 3...         75000
# 251039  {'city': 'PARIS', 'street': 'RUE MICHEL ANGE 3...        173076
#
#                type                  website_x     rcn              acronym  \
# 0       participant         www.baesystems.com  101114        ACTUATION2015
# 1       participant  http://www1.hut.edu.vn/en  206608               SEAGAL
# 2       participant                             189108               VIMSEN
# 3       participant                              90329            SETATWORK
# 4       participant                www.rega.ch  206615                HEDGE
# ...             ...                        ...     ...                  ...
# 251035  coordinator                www.cnrs.fr   98892   Bird Vocal Network
# 251036  coordinator                www.cnrs.fr  107868  gas trapping in ice
# 251037  coordinator                www.cnrs.fr  109814             NIEDPWIT
# 251038  coordinator                www.cnrs.fr  210724   SRBMETABONOXSTRESS
# 251039  coordinator                www.cnrs.fr  212174         NanoOsmDiode
#
#        end_date_code  ...  total_cost                     website_y  \
# 0         2016-04-30  ...    34373653  http://www.actuation2015.eu/
# 1         2010-11-14  ...      548229
# 2         2017-01-31  ...     3331399
# 3         2010-08-31  ...     1207388
# 4         2011-05-14  ...     1192235
# ...              ...  ...         ...                           ...
# 251035           NaT  ...      250659
# 251036           NaT  ...      280254
# 251037           NaT  ...      261385
# 251038           NaT  ...       75000
# 251039           NaT  ...      173076
#
#                id                                               name  \
# 0       -99679701                   BAE SYSTEMS (OPERATIONS) LIMITED
# 1       -99552481                     Hanoi University of Technology
# 2       -99525116                 COSMOTE KINITES TILEPIKOINONIES AE
# 3       -99524889                 CONFEDERATION OF DANISH INDUSTRIES
# 4       -99449792                            Swiss Air Ambulance LTD
# ...           ...                                                ...
# 251035  999997930  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS
# 251036  999997930  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS
# 251037  999997930  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS
# 251038  999997930  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS
# 251039  999997930  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS
#
#        country_code    country_name num_success multiple_success  \
# 0                GB  United Kingdom           0                0
# 1                VN         Vietnam           0                0
# 2                GR          Greece           0                0
# 3                DK         Denmark           0                0
# 4                CH     Switzerland           0                0
# ...             ...             ...         ...              ...
# 251035           FR          France        2695             2699
# 251036           FR          France        2696             2699
# 251037           FR          France        2697             2699
# 251038           FR          France        2698             2699
# 251039           FR          France        2699             2699
#
#        group_multiple_success  \
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0
# ...                       ...
# 251035                      1
# 251036                      1
# 251037                      1
# 251038                      1
# 251039                      1
#
#                                        funded_under_title
# 0       Specific Programme "Cooperation": Transport (i...
# 1       Specific Programme "Cooperation": Transport (i...
# 2       Specific Programme "Cooperation": Information ...
# 3                Specific Programme "Cooperation": Energy
# 4       Specific Programme "Cooperation": Transport (i...
# ...                                                   ...
# 251035  Specific programme "People" implementing the S...
# 251036  Specific programme "People" implementing the S...
# 251037  Specific programme "People" implementing the S...
# 251038  Specific programme "People" implementing the S...
# 251039  Nurturing excellence by means of cross-border ...
#
# [251040 rows x 29 columns]

# %% [markdown]
# # Prepare data set 1

# %%
cordis_full_df_filtered_num_success = cordis_full_df_sorted[cordis_full_df_sorted['num_success'] == 0]
cordis_full_df_group_multiple_success = cordis_full_df_filtered_num_success[['contribution', 'ec_contribution','total_cost','group_multiple_success']]

# %%
normalized_df_group_multiple_success = (cordis_full_df_group_multiple_success-cordis_full_df_group_multiple_success.mean())/cordis_full_df_group_multiple_success.std()
normalized_df_group_multiple_success['group_multiple_success'] = cordis_full_df_group_multiple_success['group_multiple_success']

# %%
normalized_df_group_multiple_success[10000:10020]

# %%
sns.pairplot(normalized_df_group_multiple_success, hue='group_multiple_success', diag_kind='hist')

# %% [markdown]
# # Logistic regrssion + SVM 1

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.model_selection import RandomizedSearchCV
import scipy.stats as ss

# %%
X, y = normalized_df_group_multiple_success[['contribution', 'ec_contribution','total_cost']], normalized_df_group_multiple_success['group_multiple_success']
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    train_size=0.8,  # Iris is a pretty easy task so we make it a little harder
    shuffle=True,
    random_state=42,
)

# %%
lr_model = LogisticRegression(solver='lbfgs', penalty='none')
lr_model.fit(X_train, y_train)

# %%
(pd.DataFrame(lr_model.coef_, columns=X.columns, index=['Results'])
 .assign(intercept=lr_model.intercept_)
 .assign(train_accuracy=lr_model.score(X_train, y_train)) # Train score
 .assign(test_accuracy=lr_model.score(X_test, y_test)) # Test score
 .T
)

# %%
y_train.value_counts()

# %%
cv_kwargs = dict(scoring='accuracy', cv=5, n_jobs=-1, verbose=0)
scores = cross_val_score(lr_model, X_train, y_train, **cv_kwargs)
print(f"Average cross val score: {scores.mean():.3f} (+/- {scores.std() * 2:.3f})")

# %%
param_grid = [{'C': [0.1, 1, 10, 100],
               'penalty': ['l1', 'l2'],
               'solver': ['liblinear'],
               'max_iter': [1000],
              'intercept_scaling': [0.00010, 0.1, 0.5, 1, 5, 10]},
             {'solver': ['lbfgs'], 'penalty': ['none']}]

grid = GridSearchCV(lr_model, param_grid, **cv_kwargs)
grid.fit(X_train, y_train)

print(f"Best parameters: {grid.best_params_}, with score {grid.best_score_:.3f}")

# %%
svm_model = SVC(C=1, kernel='rbf', gamma='auto')
cross_val_score(svm_model, X_train, y_train, **cv_kwargs).mean()

# %%
scores = cross_val_score(
    svm_model, X_train, y_train, cv=5, scoring='f1',
)
print(f"Average cross val score: {scores.mean():.3f} (+/- {scores.std() * 2:.3f})")

# %%
cv_kwargs['scoring'] = 'f1'
